# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_4588\2030499723.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("loan_data.csv")
df.sample(10)
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 3   LP001008    Male      No           0      Graduate            No
# 17  LP001068    Male     Yes           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 13  LP001041    Male     Yes           0      Graduate           NaN
# 12  LP001038    Male     Yes           0  Not Graduate            No
# 22  LP001097    Male      No           1      Graduate           Yes
# 21  LP001095    Male      No           0      Graduate            No
# 20  LP001087  Female      No           2      Graduate           NaN
# 5   LP001024    Male     Yes           2      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount Loan_Amount_Term  \
# 3              6000                  0         141              360
# 17             2799               2253         122              360
# ...

# %%
df.isnull().mean()
# Out:
# Loan_ID              0.000000
# Gender               0.043478
# Married              0.000000
# Dependents           0.000000
# Education            0.000000
# Self_Employed        0.130435
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           0.000000
# Loan_Amount_Term     0.043478
# Credit_History       0.043478
# Property_Area        0.086957
# Loan_Status          0.130435
# dtype: float64

# %%
ddf=df[["Gender","Self_Employed","Loan_Amount_Term","Credit_History","Loan_Status"]]
len(ddf.sample())/len(df)
# Out:
# 0.043478260869565216

# %%
ddf_=ddf.dropna()

# %%
ddf_
# Out:
#     Gender Self_Employed Loan_Amount_Term Credit_History Loan_Status
# 0     Male            No              360              1           N
# 1     Male           Yes              360              1           Y
# 2     Male            No              360              1           Y
# 3     Male            No              360              1           Y
# 4     Male            No              360              1           Y
# 5     Male            No              360              1           Y
# 7     Male            No              360              1           N
# 8     Male            No              120              1           Y
# 9     Male            No              360              1           Y
# 11  Female            No              360              0           N
# 12    Male            No              360              1           N
# 14    Male            No              360              0           N
# 15    Male            No              360              0           N
# ...

# %%
print("The shape of old data is:",ddf.shape,"And the shape of he new data is:",ddf_.shape)
# Out:
# The shape of old data is: (23, 5) And the shape of he new data is: (16, 5)

# %%
print("OLD Loan_Status")
print(sns.histplot(data=df["Loan_Status"]))
print("NEW Loan_Status")
print(sns.histplot(data=ddf_["Loan_Status"]))
# Out:
# OLD Loan_Status
# Axes(0.125,0.11;0.775x0.77)
# NEW Loan_Status
# Axes(0.125,0.11;0.775x0.77)

# %%
print("OLD Loan_Status")
print(sns.barplot(data=df["Loan_Status"]))
print("NEW Loan_Status")
print(sns.barplot(data=ddf_["Loan_Status"]))
# Out:
# OLD Loan_Status
# Axes(0.125,0.11;0.775x0.77)
# NEW Loan_Status
# Axes(0.125,0.11;0.775x0.77)
