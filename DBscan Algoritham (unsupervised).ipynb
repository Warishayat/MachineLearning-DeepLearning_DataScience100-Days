# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_circles

# %%
x,_=make_circles(n_samples=500,factor=.5,noise=.03,random_state=4)

# %%
plt.scatter(x[:,0],x[:,1],cmap="viridis")
plt.show()
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_5984\4146419256.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x[:,0],x[:,1],cmap="viridis")

# %%
#object of the model
db=DBSCAN(eps=.1,min_samples=5)
#fit data into the model
clutser=db.fit_predict(x)

#plot the data
plt.scatter(x[:,0],x[:,1],c=clutser,cmap="viridis",marker="o")
plt.title("DBSCAN CLUSTER")
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show()
