# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_1500\3814739692.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#Simple linear is supervised mechine learning algoritham.
#it is the simple algoritham.
# there are thjree type of linear regression
# 1:simple linear regression--->one input and one output columns
# 2:multi linear regression--->more then one input columns in input.
# 3:polynomial linear regression-->its  not for not sort of linear data.

# %%
df=pd.read_csv("placement1.csv")

# %%
df.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
df.columns
# Out:
# Index(['cgpa', 'package'], dtype='object')

# %%
plt.scatter(df["cgpa"],df["package"])
plt.plot(x_train,lr.predict(x_train))
plt.xlabel("Cgpa")
plt.ylabel("Package")
plt.show()

# %%
x=df[["cgpa"]]
y=df[["package"]]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
lr=LinearRegression()

# %%
# y=mx+b where m is slope and x is value of weight and b is he intercept

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test.head(4)
y_test.head(5)
# Out:
#      package
# 112     4.10
# 29      3.49
# 182     2.08
# 199     2.33
# 193     1.94

# %%
lr.intercept_ #b values
# Out:
# array([-0.89611192])

# %%
lr.coef_  #m values
# Out:
# array([[0.55795197]])

# %%
lr.predict([[7.15]])
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.09324469]])

# %%
y_test
# Out:
#      package
# 112     4.10
# 29      3.49
# 182     2.08
# 199     2.33
# 193     1.94
# 85      1.48
# 10      1.86
# 54      3.09
# 115     4.21
# 35      2.87
# 12      3.65
# 92      4.00
# 13      2.89
# 126     2.60
# 174     2.99
# 2       3.25
# 44      1.86
# 3       3.67
# 113     2.37
# 14      3.42
# 23      2.48
# 25      3.65
# 6       2.60
# 134     2.83
# 165     4.08
# 173     2.56
# 45      3.58
# 65      3.81
# 48      4.09
# 122     2.01
# 178     3.63
# 64      2.92
# 9       3.51
# 57      1.94
# 78      2.21
# 71      3.34
# 128     3.34
# 176     3.23
# 131     2.01
# 53      2.61
