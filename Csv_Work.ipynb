# %%
import pandas  as pd
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_10976\3692857447.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas  as pd

# %%
data=pd.read_csv("loan_data.csv",usecols=["Married","ApplicantIncome"])   #if file in the same folder
data
# Out:
#    Married  ApplicantIncome
# 0      Yes             4583
# 1      Yes             3000
# 2      Yes             2583
# 3       No             6000
# 4      Yes             2333
# 5      Yes             3200
# 6      Yes             2500
# 7       No             1853
# 8      Yes             1299
# 9       No             4950
# 10      No             3596
# 11      No             3510
# 12     Yes             4887
# 13     Yes             2600
# 14     Yes             7660
# 15     Yes             2600
# 16     Yes             3365
# 17     Yes             2799
# 18     Yes             4226
# 19      No             1442
# 20      No             3750
# 21      No             3167
# 22      No             4692

# %%
data=pd.read_csv("loan_data.csv",skiprows=[0,2])   #Skiprows
data
# Out:
#     LP001003    Male  Yes  1      Graduate   No  4583  1508  128        360  \
# 0   LP001006    Male  Yes  0  Not Graduate   No  2583  2358  120        360
# 1   LP001008    Male   No  0      Graduate   No  6000     0  141        360
# 2   LP001013    Male  Yes  0  Not Graduate   No  2333  1516   95        360
# 3   LP001024    Male  Yes  2      Graduate   No  3200   700   70        360
# 4   LP001027    Male  Yes  2      Graduate  NaN  2500  1840  109        360
# 5   LP001029    Male   No  0      Graduate   No  1853  2840  114        360
# 6   LP001030    Male  Yes  2      Graduate   No  1299  1086   17        120
# 7   LP001032    Male   No  0      Graduate   No  4950     0  125        360
# 8   LP001034    Male   No  1  Not Graduate   No  3596     0  100        240
# 9   LP001036  Female   No  0      Graduate   No  3510     0   76        360
# 10  LP001038    Male  Yes  0  Not Graduate   No  4887     0  133        360
# ...

# %%
data=pd.read_csv("loan_data.csv",nrows=12)   #restrict the numbers
data
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
#
# ...

# %%
data=pd.read_csv("loan_data.csv",encoding="latin-1")   #Encoding permater when we get Unicode Error
data
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %%
data=pd.read_csv("loan_data.csv")   #for parse Error ,error_bad_lines=False
data
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %%
data=pd.read_csv("loan_data.csv")   #for Handling Dates we pass parameter parse_dates=["date"]
data
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %%
def rename(name):
    if name=="Graduate":
        return "Grdut"
    else:
        return name
    

rename("Graduate")

data=pd.read_csv("loan_data.csv",converters={"Education":rename})   #for using functions
data
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1         Grdut            No
# 1   LP001005    Male     Yes           0         Grdut           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0         Grdut            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2         Grdut            No
# 6   LP001027    Male     Yes           2         Grdut           NaN
# 7   LP001029    Male      No           0         Grdut            No
# 8   LP001030    Male     Yes           2         Grdut            No
# 9   LP001032    Male      No           0         Grdut            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0         Grdut            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %%
data=pd.read_csv("loan_data.csv",na_values=["Graduate"])   #for na--parameter
data
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1           NaN            No
# 1   LP001005    Male     Yes           0           NaN           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0           NaN            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2           NaN            No
# 6   LP001027    Male     Yes           2           NaN           NaN
# 7   LP001029    Male      No           0           NaN            No
# 8   LP001030    Male     Yes           2           NaN            No
# 9   LP001032    Male      No           0           NaN            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0           NaN            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %%
data1=pd.read_csv("loan_data.csv",chunksize=10)   #ChunkSize to the long data
for i in data1:
    print(i)
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes           1      Graduate            No
# 1  LP001005   Male     Yes           0      Graduate           Yes
# 2  LP001006   Male     Yes           0  Not Graduate            No
# 3  LP001008   Male      No           0      Graduate            No
# 4  LP001013   Male     Yes           0  Not Graduate            No
# 5  LP001024   Male     Yes           2      Graduate            No
# 6  LP001027   Male     Yes           2      Graduate           NaN
# 7  LP001029   Male      No           0      Graduate            No
# 8  LP001030   Male     Yes           2      Graduate            No
# 9  LP001032   Male      No           0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583               1508         128               360
# 1             3000                  0          66               360
# ...
