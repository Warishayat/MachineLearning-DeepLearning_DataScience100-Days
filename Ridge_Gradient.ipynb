# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import Ridge
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_4892\1150756270.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
x,y=load_diabetes(return_X_y=True)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=12)

# %%
lr=SGDRegressor(alpha=0.001,penalty='l2',max_iter=500,learning_rate="constant",eta0=0.1)

# %%
lr.fit(x_train,y_train)
# Out:
# SGDRegressor(alpha=0.001, eta0=0.1, learning_rate='constant', max_iter=500)

# %%
p_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
print("The r2_score using sgdr:",r2_score(y_test,p_pred))
# Out:
# The r2_score using sgdr: 0.35989659077622593

# %%
print("Coef_ are:",lr.coef_)
print(lr.intercept_)
# Out:
# Coef_ are: [  -8.59273788 -118.82584378  402.05004474  264.26666698  -12.07946999
#   -59.0357114  -183.42106778  132.42683316  320.50945346  142.1351428 ]
# [156.88713487]

# %%
l2=Ridge(alpha=1.0,max_iter=500,solver="sparse_cg")

# %%
l2.fit(x_train,y_train)
# Out:
# Ridge(max_iter=500, solver='sparse_cg')

# %%
pred=l2.predict(x_test)

# %%
r2_score(y_test,pred)
# Out:
# 0.3305968958293469

# %%
print("Coef are:",l2.coef_)
# Out:
# Coef are: [  13.99709153  -54.79166964  291.10026321  196.30012151   14.65643273
#   -13.93022695 -149.40296437  124.3563592   234.6852249   122.68619101]

# %%
print("intercept_",l2.intercept_)
# Out:
# intercept_ 153.23233285548224

# %%
#Now work with my own class.

# %%
class RidgeGradient:
    def __init__(self, alpha, epoch, learning_rate):
        self.alpha = alpha
        self.epoch = epoch
        self.learning_rate = learning_rate
        self.weight_ = None
        self.intercept_ = None

    def fit(self, x_train, y_train):
        # Reshape x_train to a 2D array with ncols columns
        ncols = 10  # Adjust this value based on your desired number of columns
        x_train = np.reshape(x_train, (-1, ncols))

        # Add a column of ones for the intercept term
        x_train = np.insert(x_train, 0, 1, axis=1)

        # Initialize weights and intercept
        self.weight_ = np.ones(x_train.shape[1])
        self.intercept_ = 0

        for _ in range(self.epoch):
            # Compute gradient with regularization
            theta_der = np.dot(x_train.T, x_train).dot(self.weight_) - np.dot(x_train.T, y_train[:, np.newaxis]) - self.alpha * self.weight_

            # Update weights
            self.weight_ -= self.learning_rate * theta_der
            self.intercept_ = self.weight_[0]
            self.weight_ = self.weight_[1:]

        print("Intercept (theta_0):", self.intercept_)
        print("Weights (theta_1 to theta_n):", self.weight_)

# %%
Ridge=RidgeGradient(alpha=0.1,epoch=50,learning_rate=0.01)

# %%
x_train.shape
# Out:
# (353, 10)

# %%
y_train.shape
# Out:
# (353,)
