# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Overfiiting and underfitting acheiving low bais and low variance

# %%
x,y=make_circles(n_samples=100,noise=0.35,factor=0.1,random_state=42)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=12)

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %% [markdown]
# # Parameters tunning

# %%
from sklearn.datasets import load_breast_cancer

# %%
x,y=load_breast_cancer(return_X_y=True)

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=12)

# %%
dt=DecisionTreeClassifier(random_state=42)
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9122807017543859

# %%
rf=RandomForestClassifier(n_estimators=70,max_samples=0.25)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9385964912280702

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9385964912280702

# %%
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
y_pred=gb.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9473684210526315

# %% [markdown]
# # Oob score out of bag evaluation sampling with replacement

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=12)

# %%
random_forest=RandomForestClassifier(oob_score=True)

# %%
random_forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(oob_score=True)

# %%
random_forest.oob_score_
# Out:
# 0.9560439560439561

# %%
y_pred=random_forest.predict(x_test)
accuracy_score(y_test,y_pred)
#Oob score is little bit varyng and we can
# Out:
# 0.9298245614035088
