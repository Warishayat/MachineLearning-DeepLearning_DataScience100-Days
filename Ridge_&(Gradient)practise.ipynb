# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.datasets import load_diabetes
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_9764\99462057.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
x,y=load_diabetes(return_X_y=True)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=12)

# %%
lr=Ridge(alpha=1.0,solver='cholesky')

# %%
lr.fit(x_train,y_train)
# Out:
# Ridge(solver='cholesky')

# %%
print("coef_ are:",lr.coef_)
print("intercept_ is here:",lr.intercept_)
# Out:
# coef_ are: [  13.97469165  -54.79722769  291.10145672  196.30455308   14.63992488
#   -13.90625638 -149.41193085  124.36907322  234.67417829  122.6784252 ]
# intercept_ is here: 153.23229139583248

# %%
from sklearn.metrics import r2_score

# %%
y_pred=lr.predict(x_test)
r2_score(y_test,y_pred)*100
# Out:
# 33.059109666963835

# %%
#Now work with my own class:

# %%
class RideRegression:
    def __init__ (self,alpha=0.1):
        self.coef_ = None
        self.intercept_ =None
        self.alpha=alpha
    def FitTrian(self,x_train,y_train):
        x_train=np.insert(x_train,0,1,axis=1)
        i=np.identity(x_train.shape[1])

        result=np.linalg.inv(np.dot(x_train.T,x_train) + self.alpha * i).dot(x_train.T).dot(y_train)
        self.intercept_ = result[0]
        self.coef_=result[1:]
        print(self.coef_)
        print(self.intercept_)
    def prediction(self,x_test):
        return np.dot(x_test,self.coef_) + self.intercept_

# %%
r=RideRegression()
r.FitTrian(x_train,y_train)
y=r.prediction(x_test)
r2_score(y_test,y)*100
# Out:
# [ -36.26312222 -188.81044198  493.65870165  321.27833273  -65.18109972
#   -77.40365965 -186.52363303  124.95510877  416.30275072  128.52741355]
# 152.92320600194859
# 38.287914169449344

# %%
#Now doin the same thing with GradientDesecent formula.

# %%
class GradientDecentReg:
    def __init__(self,learning_rate,epoch,alpha=0.001):
        self.alpha=alpha
        self.learning_rate=learning_rate
        self.coef_=None
        self.intercept_=None
        self.epoch=epoch
    def FitData(self,x_train,y_train):
        self.coef_ = np.ones(x_train.shape[1])
        self.intercept_=0
        x_train=np.insert(x_train,0,1,axis=1)
        theta=np.insert(self.coef_,0,self.intercept_)
        for i in range(self.epoch):
            der_weight = np.dot(x_train.T,x_train).dot(theta) -np.dot(x_train.T,y_train) + self.alpha * theta
            theta = theta - (self.learning_rate * der_weight)
        self.intercept_ = theta[0]
        self.coef_=theta[1:]
        print(self.intercept_)
        print(self.coef_)
    def prediction(self,x_test):
        return np.dot(x_test,self.coef_) + self.intercept_

# %%
r=GradientDecentReg(learning_rate=0.005,epoch=500)

# %%
r.FitData(x_train,y_train)
# Out:
# 152.98624763337298
# [ -26.93745877 -168.97181987  490.36889906  315.22406257  -34.54826227
#   -95.65013544 -206.50712866  139.06830784  380.4767807   153.1015144 ]

# %%
y=r.prediction(x_test)

# %%
r2_score(y_test,y)*100
# Out:
# 37.42894405220717
