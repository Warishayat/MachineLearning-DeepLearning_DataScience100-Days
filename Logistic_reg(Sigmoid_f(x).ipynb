# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=41,hypercube=False,class_sep=10)

# %%
plt.scatter(x[:,0],x[:,1],c=y,cmap="winter",s=100)

# %%
def perceptron(x,y):
    x=np.insert(x,0,1,axis=1)
    weights = np.ones(x.shape[1])
    learning_rate =0.1
    for i in range(1000):
        id=np.random.randint(0,100)
        y_hat = step(np.dot(x[id],weights))
        weights= weights + learning_rate*(y[id] - y_hat)*x[id] 
    return weights[0],weights[1:]

# %%
def step(z):
    return 1 if z>0 else 0

# %%
intercept_,coef_= perceptron(x,y)
print(coef_)
print(intercept_*100)
# Out:
# [1.39448548 0.21106147]
# 90.0

# %%
# now with sigmoid function
def SIGMOID(x,y):
    x=np.insert(x,0,1,axis=1)
    weights = np.ones(x.shape[1])
    learning_rate =0.1
    for i in range(1000):
        id=np.random.randint(0,100)
        y_hat = sigmoid(np.dot(x[id],weights))
        weights= weights + learning_rate*(y[id] - y_hat)*x[id] 
    return weights[0],weights[1:]

# %%
def sigmoid(z):
    return 1/(1+ np.exp(z))

# %%
intercept_ , coef_=SIGMOID(x,y)

# %%
coef_,intercept_
# Out:
# (array([107.48589381,   8.98475479]), -14.57556710055043)

# %%
m=(coef_[0]/coef_[1])
b=(intercept_/coef_[1])
