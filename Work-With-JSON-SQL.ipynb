# %%
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_9380\573954172.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
#                                     Working with Json

# %%
#how to import json file into datafrmae
data=pd.read_json("brazil_geo.json")
data
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'id': 'AC', 'properties': ...
# 1   FeatureCollection  {'type': 'Feature', 'id': 'AL', 'properties': ...
# 2   FeatureCollection  {'type': 'Feature', 'id': 'AP', 'properties': ...
# 3   FeatureCollection  {'type': 'Feature', 'id': 'AM', 'properties': ...
# 4   FeatureCollection  {'type': 'Feature', 'id': 'BA', 'properties': ...
# 5   FeatureCollection  {'type': 'Feature', 'id': 'CE', 'properties': ...
# 6   FeatureCollection  {'type': 'Feature', 'id': 'DF', 'properties': ...
# 7   FeatureCollection  {'type': 'Feature', 'id': 'ES', 'properties': ...
# 8   FeatureCollection  {'type': 'Feature', 'id': 'GO', 'properties': ...
# 9   FeatureCollection  {'type': 'Feature', 'id': 'MA', 'properties': ...
# 10  FeatureCollection  {'type': 'Feature', 'id': 'MT', 'properties': ...
# 11  FeatureCollection  {'type': 'Feature', 'id': 'MS', 'properties': ...
# ...

# %%
#Now working with sql first we make database on xamp then import a library on the notebook.

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.9 MB 146.3 kB/s eta 0:01:21
#      --------------------------------------- 0.0/11.9 MB 164.3 kB/s eta 0:01:12
#      --------------------------------------- 0.1/11.9 MB 245.8 kB/s eta 0:00:48
#      --------------------------------------- 0.1/11.9 MB 345.9 kB/s eta 0:00:34
#       -------------------------------------- 0.2/11.9 MB 418.0 kB/s eta 0:00:28
#       -------------------------------------- 0.2/11.9 MB 573.4 kB/s eta 0:00:21
#       -------------------------------------- 0.3/11.9 MB 632.4 kB/s eta 0:00:19
#      - ------------------------------------- 0.4/11.9 MB 719.3 kB/s eta 0:00:16
# ...

# %%
import mysql.connector

# %%
connection=mysql.connector.Connect(host="localhost",user="root",password="",database="world")

# %%
City=pd.read_sql_query("SELECT * FROM CITY WHERE  ",connection)
City
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_9380\3110173952.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   City=pd.read_sql_query("SELECT * FROM CITY where name like 'india' ",connection)
# Empty DataFrame
# Columns: [ID, Name, CountryCode, District, Population]
# Index: []

# %%
Country=pd.read_sql_query("SELECT * FROM COUNTRY",connection)
Country
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_9380\3128894736.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Country=pd.read_sql_query("SELECT * FROM COUNTRY",connection)
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# ...

# %%
language=pd.read_sql_query("SELECT * FROM COUNTRYLANGUAGE",connection)
language
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_9380\1623803578.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   language=pd.read_sql_query("SELECT * FROM COUNTRYLANGUAGE",connection)
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# ...

# %%
City,Country
# Out:
# (        ID            Name CountryCode       District  Population
#  0        1           Kabul         AFG          Kabol     1780000
#  1        2        Qandahar         AFG       Qandahar      237500
#  2        3           Herat         AFG          Herat      186800
#  3        4  Mazar-e-Sharif         AFG          Balkh      127800
#  4        5       Amsterdam         NLD  Noord-Holland      731200
#  ...    ...             ...         ...            ...         ...
#  4074  4075      Khan Yunis         PSE     Khan Yunis      123175
#  4075  4076          Hebron         PSE         Hebron      119401
#  4076  4077        Jabaliya         PSE     North Gaza      113901
#  4077  4078          Nablus         PSE         Nablus      100231
#  4078  4079           Rafah         PSE          Rafah       92020
#
#  [4079 rows x 5 columns],
#      Code          Name      Continent                     Region  SurfaceArea  \
# ...

# %%
var = pd.merge(City, Country, on='Name')
print(var.columns.value_counts().sum())
# Out:
# 19

# %%
var2=pd.merge(var,language, on="CountryCode")

# %%
var2
# Out:
#       ID        Name CountryCode       District  Population_x Code  \
# 0    585    Djibouti         DJI       Djibouti        383000  DJI
# 1    585    Djibouti         DJI       Djibouti        383000  DJI
# 2    585    Djibouti         DJI       Djibouti        383000  DJI
# 3    864      Mexico         PHL  Central Luzon        109481  MEX
# 4    864      Mexico         PHL  Central Luzon        109481  MEX
# 5    864      Mexico         PHL  Central Luzon        109481  MEX
# 6    864      Mexico         PHL  Central Luzon        109481  MEX
# 7    864      Mexico         PHL  Central Luzon        109481  MEX
# 8    864      Mexico         PHL  Central Luzon        109481  MEX
# 9    864      Mexico         PHL  Central Luzon        109481  MEX
# 10   864      Mexico         PHL  Central Luzon        109481  MEX
# 11   864      Mexico         PHL  Central Luzon        109481  MEX
# 12   864      Mexico         PHL  Central Luzon        109481  MEX
# ...
