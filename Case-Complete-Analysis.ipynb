# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Today we will cover the missing value
#1: drop the values---->mean remove item
#2: impute the missing values have two type univariate and bivariate missing.
#in bivariate we using knn algo to handle missing value and  iterative imputer algo

# %%
#Today we learn how to remove missing values from the data.its is also called compete case analysis.

# %%
#IN CASE COMPLETE ANALYSIS if we found some missing value in some colum then we use to droop the complete row

# %%
#When we use CCA(Complete case analysis)
#when our data is missing at random values so we use to drop the values if we found consqutive at the first or at thevery last in the data then we use
#to impute that data.missing completely at random.( MCAR).if the data is missing under 5% then we use CCA compete case analysis.

# %%
df=pd.read_csv("data_science_job.csv")
df.head(3)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
#
#   major_discipline  experience company_size company_type  training_hours  \
# 0             STEM        20.0          NaN          NaN            36.0
# 1             STEM        15.0        50-99      Pvt Ltd            47.0
# 2             STEM         5.0          NaN          NaN            83.0
#
#    target
# 0     1.0
# 1     0.0
# 2     0.0

# %%
#To check how much the data is missing in the columns 
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
df.shape
# Out:
# (19158, 13)

# %%
#we will apply the CCA/drop values on that columns where missing data is less or to 5%.

# %%
dd=df[["training_hours","education_level","enrolled_university","city_development_index","experience"]]

# %%
dd.sample(5)
# Out:
#        training_hours education_level enrolled_university  \
# 9026             11.0         Masters       no_enrollment
# 11899            70.0     High School       no_enrollment
# 14425           113.0        Graduate       no_enrollment
# 17795            64.0         Masters       no_enrollment
# 15897            42.0     High School    Full time course
#
#        city_development_index  experience
# 9026                    0.920        20.0
# 11899                   0.920         6.0
# 14425                   0.735         2.0
# 17795                   0.903        15.0
# 15897                   0.920         5.0

# %%
sns.histplot(data=df["training_hours"])
# Out:
# <Axes: xlabel='training_hours', ylabel='Count'>

# %%
sns.kdeplot(dd["training_hours"])
# Out:
# <Axes: xlabel='training_hours', ylabel='Density'>

# %%
sns.histplot(data=dd["training_hours"])
# Out:
# <Axes: xlabel='training_hours', ylabel='Count'>

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   training_hours          18392 non-null  float64
#  1   education_level         18698 non-null  object
#  2   enrolled_university     18772 non-null  object
#  3   city_development_index  18679 non-null  float64
#  4   experience              19093 non-null  float64
# dtypes: float64(3), object(2)
# memory usage: 748.5+ KB

# %%
len(dd.dropna())/len(dd)
#Before dropin the rows the data is:
print(dd.shape)
# Out:
# (19158, 5)

# %%
data=dd.dropna(inplace=True)
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_6740\1858763369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data=dd.dropna(inplace=True)

# %%
#After droping the rows the new data is 
print(dd.shape)
# Out:
# (17182, 5)

# %%
sns.histplot(data=dd["training_hours"])
# Out:
# <Axes: xlabel='training_hours', ylabel='Count'>

# %%
sns.kdeplot(data=dd["training_hours"]) #its applying on the new data
# Out:
# <Axes: xlabel='training_hours', ylabel='Density'>

# %%
sns.histplot(data=dd["city_development_index"])
# Out:
# <Axes: xlabel='city_development_index', ylabel='Count'>

# %%
sns.kdeplot(data=dd["city_development_index"])
# Out:
# <Axes: xlabel='city_development_index', ylabel='Density'>
