# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.datasets import load_diabetes
from sklearn.linear_model import Ridge,LinearRegression
from sklearn.model_selection import train_test_split

# %%
x,y=load_diabetes(return_X_y=True)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.shape
# Out:
# (353, 10)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
lr.intercept_
# Out:
# 151.88331005254167

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %% [raw]
# #Now applying the ridge regression  mean we are adding some extra information to prevent the model from overfiting

# %%
rr=Ridge(alpha=0.2)

# %%
rr.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.2)

# %%
rr.intercept_
# Out:
# 151.92615161768433

# %%
rr.coef_
# Out:
# array([  16.52944546, -148.66970088,  446.64285254,  294.10244533,
#         -38.44275752,  -83.50387158, -174.68566554,   94.70456458,
#         428.55564708,   85.24665306])

# %%
x.shape
# Out:
# (442, 10)

# %%
y_pred=rr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.45353669074105607
