# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x,y=load_diabetes(return_X_y=True)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
lr=LinearRegression()

# %% [raw]
# lr.

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
lr.intercept_
# Out:
# 151.88331005254167

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
print("The adjusted r2 score is:",r2_score(y_test,y_pred))
# Out:
# The adjusted r2 score is: 0.4399338661568968

# %%
#Now Make the coede from scratch

# %%
class MinniBatchGradient:
    def __init__(self,learning_rate,batch_size,epoch):
        self.coef_=None
        self.intercept_=None
        self.epoch=epoch
        self.lr=learning_rate
        self.batch_size=batch_size
    def fit_data(self,x_train,y_train):
        self.coef_ =np.ones(x_train.shape[1])
        self.intercept_ = 0
        for i in range(self.epoch):
            for j in range(int(x_train.shape[0]/self.batch_size)):
                idx=random.sample(range(x_train.shape[0]),self.batch_size)
                #for intercept_ value
                y_hat = np.dot(x_train[idx],self.coef_) + self.intercept_
                der_intercept = -2 * np.mean(y_train[idx] - y_hat)
                self.intercept_=self.intercept_ - (self.lr * der_intercept)

                #Now for coef_
                der_coef = - 2 * np.dot((y_train[idx] - y_hat),x_train[idx])
                self.coef_ = self.coef_ - (self.lr * der_coef)
        print("intercept_ value is here:",self.intercept_)
        print("coef_ is here:",self.coef_)

    def prediction(self,x_test):
        return np.dot(x_test,self.coef_) + self.intercept_

# %%
import random
mbg=MinniBatchGradient(learning_rate=0.1,batch_size=int(x_train.shape[0]/10),epoch=50)

# %%
mbg.fit_data(x_train,y_train)
y_pred=mbg.prediction(x_test)
# Out:
# intercept_ value is here: 155.19026970763935
# coef_ is here: [ -24.91498848 -203.30849473  542.96689565  349.66660298  -84.9383578
#  -126.53280828 -177.12579826   66.01733915  531.16342552   58.47299042]

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4441421435070031
