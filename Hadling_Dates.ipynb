# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dates=pd.read_csv("orders.csv")
dates.head(2)
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157

# %%
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
dates["date"]=pd.to_datetime(dates["date"])

# %%
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
#Now apply dunction
dates["date_month"]=dates["date"].dt.month_name()
dates.head(4)
# Out:
#         date  product_id  city_id  orders date_month  date_year  date_day
# 0 2019-12-10        5628       25       3   December       2019        10
# 1 2018-08-15        3646       14     157     August       2018        15
# 2 2018-10-23        1859       25       1    October       2018        23
# 3 2019-08-17        7292       25       1     August       2019        17

# %%
#Now apply dunction
dates["date_year"]=dates["date"].dt.year
dates.head(5)
# Out:
#         date  product_id  city_id  orders  date_month  date_year
# 0 2019-12-10        5628       25       3          12       2019
# 1 2018-08-15        3646       14     157           8       2018
# 2 2018-10-23        1859       25       1          10       2018
# 3 2019-08-17        7292       25       1           8       2019
# 4 2019-01-06        4344       25       3           1       2019

# %%
#Now apply dunction
dates["date_day"]=dates["date"].dt.day
dates.head(5)
# Out:
#         date  product_id  city_id  orders date_month  date_year  date_day  \
# 0 2019-12-10        5628       25       3   December       2019        10
# 1 2018-08-15        3646       14     157     August       2018        15
# 2 2018-10-23        1859       25       1    October       2018        23
# 3 2019-08-17        7292       25       1     August       2019        17
# 4 2019-01-06        4344       25       3    January       2019         6
#
#    MOnth_agust  week_day  week_Quarter
# 0            0         4             4
# 1            1         3             3
# 2            0         4             4
# 3            1         3             3
# 4            0         1             1

# %%
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
#  4   date_month  1000 non-null   int32
#  5   date_year   1000 non-null   int32
#  6   date_day    1000 non-null   int32
# dtypes: datetime64[ns](1), int32(3), int64(3)
# memory usage: 43.1 KB

# %%
#to check is tis weekend.
dates["MOnth_agust"]=np.where(dates["date_month"].isin(["August"]),1,0)

# %%
dates.head(20)
# Out:
#          date  product_id  city_id  orders date_month  date_year  date_day  \
# 0  2019-12-10        5628       25       3   December       2019        10
# 1  2018-08-15        3646       14     157     August       2018        15
# 2  2018-10-23        1859       25       1    October       2018        23
# 3  2019-08-17        7292       25       1     August       2019        17
# 4  2019-01-06        4344       25       3    January       2019         6
# 5  2018-08-23        1811       25       4     August       2018        23
# 6  2018-11-21        1282       26       1   November       2018        21
# 7  2019-03-27        5022        2      41      March       2019        27
# 8  2019-06-29        3699        3      15       June       2019        29
# 9  2018-08-30        4373       11       3     August       2018        30
# 10 2019-10-24        6339       26       1    October       2019        24
# ...

# %%
dates["week_Quarter"]=dates["date"].dt.quarter
dates.head(20)
# Out:
#          date  product_id  city_id  orders date_month  date_year  date_day  \
# 0  2019-12-10        5628       25       3   December       2019        10
# 1  2018-08-15        3646       14     157     August       2018        15
# 2  2018-10-23        1859       25       1    October       2018        23
# 3  2019-08-17        7292       25       1     August       2019        17
# 4  2019-01-06        4344       25       3    January       2019         6
# 5  2018-08-23        1811       25       4     August       2018        23
# 6  2018-11-21        1282       26       1   November       2018        21
# 7  2019-03-27        5022        2      41      March       2019        27
# 8  2019-06-29        3699        3      15       June       2019        29
# 9  2018-08-30        4373       11       3     August       2018        30
# 10 2019-10-24        6339       26       1    October       2019        24
# ...

# %%
time=pd.read_csv("messages (1).csv")
time.head(3)
# Out:
#                   date                                               msg
# 0  2013-12-15 00:50:00                          ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00  ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00          Днепр.м 43 позн.с д/ж *.о  067.16.34.576

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
time["date"]=pd.to_datetime(time["date"])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time["time"]=time["date"].dt.time
time.head(20)
# Out:
#                   date                                                msg  \
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# 5  2016-03-08 22:52:00  пар.32прок.дев.на авто по ночн.городу.Днепр.06...
# 6  2014-02-18 00:23:00           Семейная пара познакомится для отношений
# 7  2012-11-23 01:10:00                  ДЛЯ С.П СНАЧАЛО СМС 066.679.400.8
# 8  2014-12-23 01:20:00  Дедушки ау вы где? СНЕГУРОЧКИ СКУЧАЮТ. Здесь е...
# 9  2012-11-03 23:46:00                     ищу парня с авто.063 528 90 72
# 10 2013-07-26 00:11:00  Хочу обшения на инт темы с девушкой 0500747823...
# 11 2013-12-18 00:39:00  открою дверь прохожему который хочет погреться...
# ...

# %%
time["hours"]=time["date"].dt.hour
time["Minut"]=time["date"].dt.minute
time["seconds"]=time["date"].dt.second
time.head(40)
# Out:
#                   date                                                msg  \
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# 5  2016-03-08 22:52:00  пар.32прок.дев.на авто по ночн.городу.Днепр.06...
# 6  2014-02-18 00:23:00           Семейная пара познакомится для отношений
# 7  2012-11-23 01:10:00                  ДЛЯ С.П СНАЧАЛО СМС 066.679.400.8
# 8  2014-12-23 01:20:00  Дедушки ау вы где? СНЕГУРОЧКИ СКУЧАЮТ. Здесь е...
# 9  2012-11-03 23:46:00                     ищу парня с авто.063 528 90 72
# 10 2013-07-26 00:11:00  Хочу обшения на инт темы с девушкой 0500747823...
# 11 2013-12-18 00:39:00  открою дверь прохожему который хочет погреться...
# ...
