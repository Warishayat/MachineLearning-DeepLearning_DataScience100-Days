# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
df=sns.load_dataset("iris")

# %%
df.sample
# Out:
# <bound method NDFrame.sample of      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]>

# %%
Encoder=LabelEncoder()
df["species"]=Encoder.fit_transform(df["species"])

# %%
df=df[df["species"] !=0][["sepal_length","petal_length","species"]]

# %%
plt.scatter(df["sepal_length"],df["petal_length"],c=df["species"],cmap="winter")

# %%
#Taking only 20 rows from the data

# %%
df=df.sample(100)
df_train=df.sample(20)
df_val=df.sample(10)
df_test=df.sample(10)

# %%
df_train.sample(2)
# Out:
#      sepal_length  petal_length  species
# 96            5.7           4.2        1
# 146           6.3           5.0        2

# %%
x_test=df_val.iloc[:,0:2].values
y_test=df_val.iloc[:,-1:].values

# %%
#Data for the tree.

# %%
df_bag = df_train.sample(16,replace=True,random_state=42)
x=df_bag.iloc[:,0:2]
y=df_bag.iloc[:,-1:]

# %%
df_bag
# Out:
#      sepal_length  petal_length  species
# 78            6.0           4.5        1
# 149           5.9           5.1        2
# 70            5.9           4.8        1
# 84            5.4           4.5        1
# 76            6.8           4.8        1
# 78            6.0           4.5        1
# 131           7.9           6.4        2
# 84            5.4           4.5        1
# 84            5.4           4.5        1
# 129           7.2           5.8        2
# 76            6.8           4.8        1
# 133           6.3           5.1        2
# 66            5.6           4.5        1
# 91            6.1           4.6        1
# 147           6.5           5.2        2
# 66            5.6           4.5        1

# %%
df_bag1=DecisionTreeClassifier()

# %%
evaluate(df_bag1,x,y)
# Out:
# Acuuracy got: 0.8
# C:\Users\Waris Hayyat\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
def evaluate(df_bag1,x,y):
    df_bag1.fit(x,y)
    plot_tree(df_bag1)
    y_pred=df_bag1.predict(x_test)
    print("Acuuracy got:",accuracy_score(y_test,y_pred))

# %%
df_bag2=df_train.sample(16,replace=True)
x=df_bag2.iloc[:,0:2]
y=df_bag2.iloc[:,-1:]

# %%
Model2=DecisionTreeClassifier()
evaluate(Model2,x,y)
# Out:
# Acuuracy got: 0.8
# C:\Users\Waris Hayyat\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
df_bag3=df_train.sample(16,replace=True)
x=df_bag3.iloc[:,0:2]
y=df_bag3.iloc[:,-1:]

# %%
Model3=DecisionTreeClassifier()
evaluate(Model3,x,y)
# Out:
# Acuuracy got: 0.8
# C:\Users\Waris Hayyat\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
df_bag4=df_train.sample(16,replace=True)
x=df_bag4.iloc[:,0:2]
y=df_bag4.iloc[:,-1:]

# %%
Model5=DecisionTreeClassifier()
evaluate(Model5,x,y)
# Out:
# Acuuracy got: 0.8
# C:\Users\Waris Hayyat\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
